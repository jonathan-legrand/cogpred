# %%
from skopt.space import *
import numpy as np
import matplotlib.pyplot as plt

d  = Real(1e-5, 0.1, prior="log-uniform")
values = np.stack(
    [d.rvs() for _ in range(1000)]
).squeeze()

# %%
plt.hist(values, histtype="step")
plt.xscale("log")
